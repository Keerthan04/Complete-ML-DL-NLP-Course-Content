# %% [markdown]
# # Tokenization Implementation
# nltk is used

# %%
corpus = '''The Zen of Python, by Tim Peters
Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
'''

# %%
## tokenization
## paragraph to sentences
from nltk.tokenize import sent_tokenize #paragraph to sentences

# %%
sentences = sent_tokenize(corpus)
sentences#get all the sentences as as list,based on . and ! and all it does separate to diff sentences
# Out:
# ['The Zen of Python, by Tim Peters\nBeautiful is better than ugly.',
#  'Explicit is better than implicit.',
#  'Simple is better than complex.',
#  'Complex is better than complicated.',
#  'Flat is better than nested.',
#  'Sparse is better than dense.',
#  'Readability counts.',
#  "Special cases aren't special enough to break the rules.",
#  'Although practicality beats purity.',
#  'Errors should never pass silently.',
#  'Unless explicitly silenced.',
#  'In the face of ambiguity, refuse the temptation to guess.',
#  'There should be one-- and preferably only one --obvious way to do it.',
#  "Although that way may not be obvious at first unless you're Dutch.",
#  'Now is better than never.',
#  'Although never is often better than *right* now.',
#  "If the implementation is hard to explain, it's a bad idea.",
#  'If the implementation is easy to explain, it may be a good idea.',
#  "Namespaces are one honking great idea -- let's do more of those!"]

# %%
## Convert a paragraph into words also sentence into words
from nltk.tokenize import word_tokenize
words = word_tokenize(corpus)
words#list of words we get
#the . , * -- ! and all have been considered as a different word in this
# Out:
# ['The',
#  'Zen',
#  'of',
#  'Python',
#  ',',
#  'by',
#  'Tim',
#  'Peters',
#  'Beautiful',
#  'is',
#  'better',
#  'than',
#  'ugly',
#  '.',
#  'Explicit',
#  'is',
#  'better',
#  'than',
#  'implicit',
#  '.',
#  'Simple',
#  'is',
#  'better',
#  'than',
#  'complex',
#  '.',
#  'Complex',
#  'is',
#  'better',
#  'than',
#  'complicated',
#  '.',
#  'Flat',
#  'is',
#  'better',
#  'than',
#  'nested',
#  '.',
#  'Sparse',
#  'is',
#  'better',
#  'than',
#  'dense',
#  '.',
#  'Readability',
#  'counts',
#  '.',
#  'Special',
#  'cases',
#  'are',
#  "n't",
#  'special',
#  'enough',
#  'to',
#  'break',
#  'the',
#  'rules',
#  '.',
#  'Although',
#  'practicality',
#  'beats',
#  'purity',
#  '.',
#  'Errors',
#  'should',
#  'never',
#  'pass',
#  'silently',
#  '.',
#  'Unless',
#  'explicitly',
#  'silenced',
#  '.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'ambiguity',
#  ',',
#  'refuse',
#  'the',
#  'temptation',
#  'to',
#  'guess',
#  '.',
#  'There',
# ...

# %%
for sentence in sentences:
    print(word_tokenize(sentence))
# Out:
# ['The', 'Zen', 'of', 'Python', ',', 'by', 'Tim', 'Peters', 'Beautiful', 'is', 'better', 'than', 'ugly', '.']
# ['Explicit', 'is', 'better', 'than', 'implicit', '.']
# ['Simple', 'is', 'better', 'than', 'complex', '.']
# ['Complex', 'is', 'better', 'than', 'complicated', '.']
# ['Flat', 'is', 'better', 'than', 'nested', '.']
# ['Sparse', 'is', 'better', 'than', 'dense', '.']
# ['Readability', 'counts', '.']
# ['Special', 'cases', 'are', "n't", 'special', 'enough', 'to', 'break', 'the', 'rules', '.']
# ['Although', 'practicality', 'beats', 'purity', '.']
# ['Errors', 'should', 'never', 'pass', 'silently', '.']
# ['Unless', 'explicitly', 'silenced', '.']
# ['In', 'the', 'face', 'of', 'ambiguity', ',', 'refuse', 'the', 'temptation', 'to', 'guess', '.']
# ['There', 'should', 'be', 'one', '--', 'and', 'preferably', 'only', 'one', '--', 'obvious', 'way', 'to', 'do', 'it', '.']
# ['Although', 'that', 'way', 'may', 'not', 'be', 'obvious', 'at', 'first', 'unless', 'you', "'re", 'Dutch', '.']
# ...

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
#this also does same with some diff like if dont's then dont ' s as diff words it does so like those this does
# Out:
# ['The',
#  'Zen',
#  'of',
#  'Python',
#  ',',
#  'by',
#  'Tim',
#  'Peters',
#  'Beautiful',
#  'is',
#  'better',
#  'than',
#  'ugly',
#  '.',
#  'Explicit',
#  'is',
#  'better',
#  'than',
#  'implicit',
#  '.',
#  'Simple',
#  'is',
#  'better',
#  'than',
#  'complex',
#  '.',
#  'Complex',
#  'is',
#  'better',
#  'than',
#  'complicated',
#  '.',
#  'Flat',
#  'is',
#  'better',
#  'than',
#  'nested',
#  '.',
#  'Sparse',
#  'is',
#  'better',
#  'than',
#  'dense',
#  '.',
#  'Readability',
#  'counts',
#  '.',
#  'Special',
#  'cases',
#  'aren',
#  "'",
#  't',
#  'special',
#  'enough',
#  'to',
#  'break',
#  'the',
#  'rules',
#  '.',
#  'Although',
#  'practicality',
#  'beats',
#  'purity',
#  '.',
#  'Errors',
#  'should',
#  'never',
#  'pass',
#  'silently',
#  '.',
#  'Unless',
#  'explicitly',
#  'silenced',
#  '.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'ambiguity',
#  ',',
#  'refuse',
#  'the',
#  'temptation',
#  'to',
#  'guess',
#  '.',
#  'There',
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
#again diff tokenizer but better and . is not treated as a separate word it will be treated as part of previous word except in last the full stop is treated as a diff word
# Out:
# ['The',
#  'Zen',
#  'of',
#  'Python',
#  ',',
#  'by',
#  'Tim',
#  'Peters',
#  'Beautiful',
#  'is',
#  'better',
#  'than',
#  'ugly.',
#  'Explicit',
#  'is',
#  'better',
#  'than',
#  'implicit.',
#  'Simple',
#  'is',
#  'better',
#  'than',
#  'complex.',
#  'Complex',
#  'is',
#  'better',
#  'than',
#  'complicated.',
#  'Flat',
#  'is',
#  'better',
#  'than',
#  'nested.',
#  'Sparse',
#  'is',
#  'better',
#  'than',
#  'dense.',
#  'Readability',
#  'counts.',
#  'Special',
#  'cases',
#  'are',
#  "n't",
#  'special',
#  'enough',
#  'to',
#  'break',
#  'the',
#  'rules.',
#  'Although',
#  'practicality',
#  'beats',
#  'purity.',
#  'Errors',
#  'should',
#  'never',
#  'pass',
#  'silently.',
#  'Unless',
#  'explicitly',
#  'silenced.',
#  'In',
#  'the',
#  'face',
#  'of',
#  'ambiguity',
#  ',',
#  'refuse',
#  'the',
#  'temptation',
#  'to',
#  'guess.',
#  'There',
#  'should',
#  'be',
#  'one',
#  '--',
#  'and',
#  'preferably',
#  'only',
#  'one',
# ...
